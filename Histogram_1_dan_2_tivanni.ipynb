# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_sp = cv2.imread('../Phyton/sp.jpg')
RGB_sp = cv2.cvtColor(img_sp, cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-dbaad097afdd> in <module>
#       1 img_sp = cv2.imread('../Phyton/sp.jpg')
# ----> 2 RGB_sp = cv2.cvtColor(img_sp, cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.2.0) ..\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
img_rainbow = cv2.imread('../Phyton/spt.jpg')
RGB_rainbow = cv2.cvtColor(img_rainbow, cv2.COLOR_BGR2RGB)

# %%
img_bricks = cv2.imread('../Phyton/sq.jpg')
RGB_bricks = cv2.cvtColor(img_bricks, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(RGB_sp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e3bc59970f11> in <module>
# ----> 1 plt.imshow(RGB_sp)
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(img_sp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f1928a494a08> in <module>
# ----> 1 plt.imshow(img_sp)
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(img_rainbow)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ed2bd73e5ccb> in <module>
# ----> 1 plt.imshow(img_rainbow)
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(img_bricks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-719be934b5df> in <module>
# ----> 1 plt.imshow(img_bricks)
#
# NameError: name 'plt' is not defined

# %%
hist_values = cv2.calcHist([img_bricks],channels=[0],mask=None,histSize=[256],ranges=[0,256])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0ef43fcb4c57> in <module>
# ----> 1 hist_values = cv2.calcHist([img_bricks],channels=[0],mask=None,histSize=[256],ranges=[0,256])
#
# NameError: name 'cv2' is not defined

# %%
hist_values.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ae1e50d251b9> in <module>
# ----> 1 hist_values.shape
#
# NameError: name 'hist_values' is not defined

# %%
plt.plot(hist_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-94abf69a8c85> in <module>
# ----> 1 plt.plot(hist_values)
#
# NameError: name 'plt' is not defined

# %%
hist_values = cv2.calcHist([img_sp],channels=[0],mask=None,histSize=[256],ranges=[0,256])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9717792d8cd8> in <module>
# ----> 1 hist_values = cv2.calcHist([img_sp],channels=[0],mask=None,histSize=[256],ranges=[0,256])
#
# NameError: name 'cv2' is not defined

# %%
plt.plot(hist_values)

# %%
plt.imshow(RGB_sp)

# %%
img = RGB_bricks
color = ('b','g','r')
for i, col in enumerate(color):
    histr = cv2.calcHist([img],[i],mask=None,histSize=[256],ranges=[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.title('Blue Bricks Image')
plt.show()

# %%
img = RGB_sp
color = ('b','g','r')
for i, col in enumerate(color):
    histr= cv2.calcHist([img],[i],mask=None,histSize=[256],ranges=[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.title('Dark Spongebob')
plt.show()

# %%
img = RGB_rainbow
color = ('b','g','r')
for i, col in enumerate(color):
    histr= cv2.calcHist([img],[i],mask=None,histSize=[256],ranges=[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.title('Rainbow Image')
plt.show()

# %%
img = RGB_rainbow

# %%
img.shape
# Out:
# (510, 680, 3)

# %%
mask = np.zeros(img.shape[:2], np.uint8)
mask[300:400, 100:400] = 255

# %%
plt.imshow(mask, cmap='gray')

# %%
masked_img = cv2.bitwise_and(img,img,mask = mask)
show_masked_img = cv2.bitwise_and(RGB_rainbow,RGB_rainbow,mask = mask)

# %%
plt.imshow(show_masked_img)

# %%
hist_mask_values_red = cv2.calcHist([img_rainbow],channels=[2],mask=mask,histSize=[256],ranges=[0,256])
hist_full_values_red = cv2.calcHist([RGB_rainbow],channels=[2],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_full_values_red)
plt.title('Histogram untuk warna merah full image')
# Out:
# Text(0.5, 1.0, 'Histogram untuk warna merah full image')

# %%
plt.plot(hist_mask_values_red)
plt.title('Histogram RED layer untuk Masked Area')
# Out:
# Text(0.5, 1.0, 'Histogram RED layer untuk Masked Area')

# %%
gorilla = cv2.imread('nn.jpg',0)

# %%
def display(img,cmap=None):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap)

# %%
display(gorilla,cmap='gray')

# %%
hist_values = cv2.calcHist([gorilla],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
eq_gorilla = cv2.equalizeHist(gorilla)

# %%
display(eq_gorilla,cmap='gray')

# %%
hist_values = cv2.calcHist([eq_gorilla],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
color_gorilla = cv2.imread('nn.jpg')
show_gorilla = cv2.cvtColor(color_gorilla,cv2.COLOR_BGR2RGB)
# Convert to HSV colorspace
hsv = cv2.cvtColor(color_gorilla, cv2.COLOR_BGR2HSV)

# %%
display(show_gorilla)

# %%
hsv[:,:,2]
# Out:
# array([[157, 157, 157, ..., 156, 156, 156],
#        [157, 157, 157, ..., 156, 156, 156],
#        [157, 157, 157, ..., 156, 156, 156],
#        ...,
#        [121, 121, 121, ..., 121, 121, 121],
#        [121, 121, 121, ..., 121, 121, 121],
#        [121, 121, 121, ..., 121, 121, 121]], dtype=uint8)

# %%
hsv[:,:,2] = cv2.equalizeHist(hsv[:,:,2])

# %%
eq_color_gorilla = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
display(eq_color_gorilla)
